# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import urllib.request
import zipfile
import io

import pandas as pd

g_cols = ['Political Unit', 'Continent', 'Glacier Name', 'Latitude', 'Longitude', 'Maximum Elvation', 'Glacier Area']
glaciers = pd.read_csv('/content/drive/MyDrive/data/glacier/database.csv', sep=',', names=g_cols, usecols=g_cols)

print(glaciers)
# Out:
#        Political Unit       Continent Glacier Name    Latitude      Longitude  \
# 0          Glacier ID  Political Unit    Continent  Basin Code  Location Code
# 1        AF5Q112B0001     AFGHANISTAN         ASIA        Q112             B0
# 2        AF5Q112B0002     AFGHANISTAN         ASIA        Q112             B0
# 3        AF5Q112B0003     AFGHANISTAN         ASIA        Q112             B0
# 4        AF5Q112B0004     AFGHANISTAN         ASIA        Q112             B0
# ...               ...             ...          ...         ...            ...
# 132886   ZR3B410A1002           ZAIRE       AFRICA        B410             A1
# 132887   ZR3B410A1003           ZAIRE       AFRICA        B410             A1
# 132888   ZR3B410A2002           ZAIRE       AFRICA        B410             A2
# 132889   ZR3B410A3001           ZAIRE       AFRICA        B410             A3
# 132890   ZR3B410A4009           ZAIRE       AFRICA        B410             A4
#
#        Maximum Elvation     Glacier Area
# 0          Glacier Code     Glacier Name
# 1                     1              NaN
# 2                     2              NaN
# 3                     3              NaN
# 4                     4              NaN
# ...                 ...              ...
# 132886                2        KRAEPELIN
# 132887                3  NORTH-KRAEPELIN
# 132888                2           ALBERT
# 132889                1        ALEXANDRA
# 132890                9     WEST STANLEY
#
# [132891 rows x 7 columns]
# <ipython-input-12-8c4280e29434>:8: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   glaciers = pd.read_csv('/content/drive/MyDrive/data/glacier/database.csv', sep=',', names=g_cols, usecols=g_cols)
